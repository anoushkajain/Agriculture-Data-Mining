# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import os

# %%
file1 = pd.read_csv("/Users/anoushkajain/Desktop/datefile1.csv")
print(file1)
# Out:
#                     Crop           State  \
# 0                  ARHAR   Uttar Pradesh
# 1                  ARHAR       Karnataka
# 2                  ARHAR         Gujarat
# 3                  ARHAR  Andhra Pradesh
# 4                  ARHAR     Maharashtra
# 5                 COTTON     Maharashtra
# 6                 COTTON          Punjab
# 7                 COTTON  Andhra Pradesh
# 8                 COTTON         Gujarat
# 9                 COTTON         Haryana
# 10                  GRAM       Rajasthan
# 11                  GRAM  Madhya Pradesh
# 12                  GRAM   Uttar Pradesh
# 13                  GRAM     Maharashtra
# 14                  GRAM  Andhra Pradesh
# 15             GROUNDNUT       Karnataka
# 16             GROUNDNUT  Andhra Pradesh
# 17             GROUNDNUT      Tamil Nadu
# 18             GROUNDNUT         Gujarat
# 19             GROUNDNUT     Maharashtra
# 20                 MAIZE           Bihar
# 21                 MAIZE       Karnataka
# ...

# %%
file2 = pd.read_csv("/Users/anoushkajain/Desktop/datafile2.csv")
print(file2)
# Out:
#             Crop               Production 2006-07  Production 2007-08  \
# 0            Total Foodgrains               158.8               168.6
# 1                        Rice               200.8               207.9
# 2                       Wheat               131.6               136.4
# 3                       Jowar               124.3               137.8
# 4                       Bajra               136.4               161.5
# 5                       Maize               198.8               249.6
# 6                        Ragi                56.1                83.6
# 7               Small millets                53.9                61.9
# 8                      Barley                88.1                79.3
# 9              Coarse Cereals               138.5               166.4
# 10                    Cereals               164.1               174.6
# 11                       Gram               140.6               127.6
# ...

# %%
file2.head()
# Out:
#   Crop               Production 2006-07  Production 2007-08  \
# 0  Total Foodgrains               158.8               168.6
# 1              Rice               200.8               207.9
# 2             Wheat               131.6               136.4
# 3             Jowar               124.3               137.8
# 4             Bajra               136.4               161.5
#
#    Production 2008-09  Production 2009-10  Production 2010-11  Area 2006-07  \
# 0               171.3               159.4               178.9         128.5
# 1               213.3               191.6               206.4         168.5
# 2               140.1               140.3               150.8         115.0
# 3               126.0               116.5               121.8         120.7
# 4               143.9               105.4               167.9          94.5
#
#    Area 2007-08  Area 2008-09  Area 2009-10  Area 2010-11  Yield 2006-07  \
# ...

# %%
file2.columns
# Out:
# Index(['Crop             ', 'Production 2006-07', 'Production 2007-08',
#        'Production 2008-09', 'Production 2009-10', 'Production 2010-11',
#        'Area 2006-07', 'Area 2007-08', 'Area 2008-09', 'Area 2009-10',
#        'Area 2010-11', 'Yield 2006-07', 'Yield 2007-08', 'Yield 2008-09',
#        'Yield 2009-10', 'Yield 2010-11'],
#       dtype='object')

# %%
k = file2[['Crop             ','Production 2006-07', 'Production 2007-08',
       'Production 2008-09', 'Production 2009-10', 'Production 2010-11']].groupby('Crop             ')
index = list(k.indices.keys())
index[-8:-2]
# Out:
# ['Total Foodgrains',
#  'Total Fruits & Vegetables',
#  'Total Non-Food grains ',
#  'Total Oilseeds',
#  'Total Pulses',
#  'Total Spices']

# %%
k.sum()[-9:-2].plot(figsize=(20,8), kind='bar');
plt.title('Year wise production different agricultural products')
plt.ylabel('Production in Quintal')
# Out:
# Text(0,0.5,'Production in Quintal')

# %%
k.sum()[:-9].plot(figsize=(20,8), kind='bar');
plt.title('Year wise production of agricultural crop')
plt.ylabel('Production in Quintal');

# %%
l = len(k['Crop             '])
fig, arraxes = plt.subplots(1,4, figsize=(12,12), sharey=True)
plt.setp(arraxes, yticks=range(len(index)), yticklabels = index)

for axes, p in zip(arraxes.flat,['Production 2006-07', 'Production 2007-08','Production 2008-09', 'Production 2009-10', 'Production 2010-11']):
    axes.barh(range(l), k[p].head())
    axes.set_title(p)
#     axes.tick_params(axis='x',  rotation=90)
#     axes.set_xticklabels(index)
fig.set_figwidth(20)

# %%
file3 = pd.read_csv("/Users/anoushkajain/Desktop/datafile3.csv")
print(file3)
# Out:
#                    Crop                            Variety  \
# 0                 Paddy         Chinsurah Rice (IET 19140)
# 1                 Paddy                     (CNI 383-5-11)
# 2                 Paddy                IGKVR-1 (IET 19569)
# 3                 Paddy                IGKVR-2 (IET 19795)
# 4                 Paddy               CR Dhan 401 (REETA)
# 5                 Paddy            CR Dhan 601 (IET 18558)
# 6                 Paddy            CR Dhan 501 (IET 19189)
# 7                 Paddy         RC Maniphou 11 (IET 20193)
# 8                 Wheat           MPO(JW)  1215 (MPO 1215)
# 9                 Wheat                          MACS 6222
# 10                Wheat                            PDW 314
# 11                Wheat                              DBW39
# 12                Wheat              VL Gehun 907 (VL 907)
# 13                Wheat                Pusa Suketi  HS 507
# 14                Wheat              Pusa Prachi (HI 1563)
# ...

# %%
file3.columns
# Out:
# Index(['Crop', 'Variety', 'Season/ duration in days', 'Recommended Zone',
#        'Unnamed: 4'],
#       dtype='object')

# %%
file2.describe()
# Out:
#        Production 2006-07  Production 2007-08  Production 2008-09  \
# count           55.000000           55.000000           55.000000
# mean           168.698182          182.629091          179.952727
# std            179.503163          199.671545          187.409253
# min             53.900000           54.400000           50.000000
# 25%            124.500000          122.200000          116.050000
# 50%            142.700000          160.100000          156.500000
# 75%            184.300000          200.100000          188.550000
# max           1427.700000         1571.500000         1463.000000
#
#        Production 2009-10  Production 2010-11  Area 2006-07  Area 2007-08  \
# count           55.000000           55.000000     55.000000     55.000000
# mean           173.749091          210.181818    116.025455    118.403636
# std            184.231322          232.535985     37.990960     41.287797
# min             42.900000           42.100000     47.900000     47.400000
# ...

# %%
file4 = pd.read_csv("/Users/anoushkajain/Desktop/produce.csv")
file4.head()
# Out:
#                                       Particulars  \
# 0              Agricultural Production Foodgrains
# 1       Agricultural Production Foodgrains Kharif
# 2         Agricultural Production Foodgrains Rabi
# 3         Agricultural Production Foodgrains Rice
# 4  Agricultural Production Foodgrains Rice Kharif
#
#                          Frequency    Unit   3-1993   3-1994   3-1995  \
# 0  Annual, Ending mar Of Each Year  Ton mn      NaN      NaN      NaN
# 1  Annual, Ending mar Of Each Year  Ton mn      NaN      NaN      NaN
# 2  Annual, Ending mar Of Each Year  Ton mn      NaN      NaN      NaN
# 3  Annual, Ending mar Of Each Year  Ton mn      NaN      NaN      NaN
# 4  Annual, Ending mar Of Each Year  Ton mn      NaN      NaN      NaN
#
#     3-1996   3-1997   3-1998   3-1999    ...        3-2005    3-2006  \
# 0      NaN      NaN      NaN      NaN    ...     198.36282  208.6016
# 1      NaN      NaN      NaN      NaN    ...     103.30942  109.8734
# ...

# %%
file5 = pd.read_csv("/Users/anoushkajain/Desktop/datafile.csv")
file5.head()
# Out:
#              Crop  2004-05  2005-06  2006-07  2007-08  2008-09  2009-10  \
# 0            Rice    100.0    101.0     99.0    105.0    112.0    121.0
# 1           Wheat    100.0    101.0    112.0    115.0    117.0    127.0
# 2  Coarse Cereals    100.0    107.0    110.0    115.0    113.0    123.0
# 3          Pulses    100.0    108.0    134.0    124.0    124.0    146.0
# 4     Vegetables     100.0    109.0    103.0    118.0    113.0    124.0
#
#    2010-11  2011-12
# 0    117.0    110.0
# 1    120.0    108.0
# 2    122.0    136.0
# 3    137.0    129.0
# 4    128.0    115.0

# %%
file4.describe()
# Out:
#         3-1993   3-1994   3-1995     3-1996        3-1997        3-1998  \
# count      3.0      4.0      4.0   6.000000     10.000000     10.000000
# mean       0.0      0.0      0.0   6.753000   1310.623000   1276.252000
# std        0.0      0.0      0.0  16.337482   4128.680346   4019.889103
# min        0.0      0.0      0.0   0.000000      0.000000      0.000000
# 25%        0.0      0.0      0.0   0.000000      0.000000      0.000000
# 50%        0.0      0.0      0.0   0.000000      0.215000      0.230000
# 75%        0.0      0.0      0.0   0.313500      3.290000      2.875000
# max        0.0      0.0      0.0  40.100000  13061.000000  12717.000000
#
#              3-1999        3-2000        3-2001        3-2002     ...       \
# count     11.000000     20.000000     22.000000     36.000000     ...
# mean    1146.230909    621.747000    588.115000    425.641667     ...
# std     3777.583647   2708.616162   2682.320751   2152.677440     ...
# ...

# %%
cols = file4.columns
print(cols)
# Out:
# Index(['Particulars', 'Frequency', 'Unit', ' 3-1993', ' 3-1994', ' 3-1995',
#        ' 3-1996', ' 3-1997', ' 3-1998', ' 3-1999', ' 3-2000', ' 3-2001',
#        ' 3-2002', ' 3-2003', ' 3-2004', ' 3-2005', ' 3-2006', ' 3-2007',
#        ' 3-2008', ' 3-2009', ' 3-2010', ' 3-2011', ' 3-2012', ' 3-2013',
#        ' 3-2014'],
#       dtype='object')

# %%
file1.columns
# Out:
# Index(['Crop', 'State', 'Cost of Cultivation (`/Hectare) A2+FL',
#        'Cost of Cultivation (`/Hectare) C2',
#        'Cost of Production (`/Quintal) C2', 'Yield (Quintal/ Hectare) '],
#       dtype='object')

# %%
file1.groupby('State').sum()
# Out:
#                 Cost of Cultivation (`/Hectare) A2+FL  \
# State
# Andhra Pradesh                              200500.69
# Bihar                                        13513.92
# Gujarat                                      79776.83
# Haryana                                      44634.24
# Karnataka                                   100129.18
# Madhya Pradesh                               30954.72
# Maharashtra                                 148360.96
# Orissa                                       22961.59
# Punjab                                       72147.43
# Rajasthan                                    59683.16
# Tamil Nadu                                   88842.92
# Uttar Pradesh                               111576.63
# West Bengal                                  24731.06
#
#                 Cost of Cultivation (`/Hectare) C2  \
# State
# Andhra Pradesh                           315029.07
# Bihar                                     19857.70
# ...

# %%
cols = file1.columns

# %%
file1.groupby('Crop')[cols[:-1]].sum().plot(kind='bar', figsize=(12,6));

# %%
file1.groupby('State')[cols[:-1]].sum().plot(kind='bar', figsize=(12,6));

# %%
plt.title('State-wise '+cols[-1], color='red', fontsize=20)
file1.groupby('State')[cols[-1]].sum().plot(kind='pie', figsize=(12,12));

# %%
plt.title('Crop-wise '+cols[-1], color='red', fontsize=20)
file1.groupby('Crop')[cols[-1]].sum().plot(kind='pie', figsize=(12,12));

# %%
file2.head()
# Out:
#   Crop               Production 2006-07  Production 2007-08  \
# 0  Total Foodgrains               158.8               168.6
# 1              Rice               200.8               207.9
# 2             Wheat               131.6               136.4
# 3             Jowar               124.3               137.8
# 4             Bajra               136.4               161.5
#
#    Production 2008-09  Production 2009-10  Production 2010-11  Area 2006-07  \
# 0               171.3               159.4               178.9         128.5
# 1               213.3               191.6               206.4         168.5
# 2               140.1               140.3               150.8         115.0
# 3               126.0               116.5               121.8         120.7
# 4               143.9               105.4               167.9          94.5
#
#    Area 2007-08  Area 2008-09  Area 2009-10  Area 2010-11  Yield 2006-07  \
# ...

# %%
file3.head()
# Out:
#     Crop                     Variety Season/ duration in days  \
# 0  Paddy  Chinsurah Rice (IET 19140)                   Medium
# 1  Paddy              (CNI 383-5-11)                      NaN
# 2  Paddy         IGKVR-1 (IET 19569)                Mid-early
# 3  Paddy         IGKVR-2 (IET 19795)                   Medium
# 4  Paddy        CR Dhan 401 (REETA)                   145-150
#
#                                     Recommended Zone  Unnamed: 4
# 0  Andhra Pradesh, Tamil Nadu, Gujarat, Orissa, a...         NaN
# 1                                                NaN         NaN
# 2  Chhattisgarh, Madhya Pradesh and Orissa under ...         NaN
# 3  Chhattisgarh, Bihar and Orissa under  both irr...         NaN
# 4  Orissa, West Bengal, Tamil Nadu and Andhra Pra...         NaN

# %%
plt.title('No of varieties per crop in India', fontsize=40, color='orange')
file3['Crop'].value_counts().plot(kind='bar', figsize= (12,12));

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
import pandas as pd

# %%
binary= pd.read_csv('/Users/anoushkajain/Desktop/datafile.csv')

# %%
binary.describe()
# Out:
#        2004-05    2005-06     2006-07     2007-08     2008-09     2009-10  \
# count     12.0   12.00000   12.000000   12.000000   12.000000   12.000000
# mean     100.0   99.75000  102.000000  104.750000  106.416667  114.916667
# std        0.0    6.64865   12.634728   10.963783   11.261022   15.900019
# min      100.0   86.00000   85.000000   87.000000   80.000000   81.000000
# 25%      100.0   96.75000   96.250000   97.750000  101.250000  106.250000
# 50%      100.0  100.00000  100.000000  102.000000  107.500000  115.500000
# 75%      100.0  103.25000  104.750000  115.000000  113.000000  123.250000
# max      100.0  109.00000  134.000000  124.000000  124.000000  146.000000
#
#           2010-11     2011-12
# count   12.000000   12.000000
# mean   121.916667  120.750000
# std     11.405408   12.800036
# min     99.000000  102.000000
# 25%    116.250000  109.500000
# 50%    122.500000  120.500000
# 75%    129.250000  130.750000
# max    138.000000  140.000000

# %%
#from sklearn.cross_validation import train_test_split
from sklearn.model_selection import train_test_split

Train,Test = train_test_split(binary, test_size = 0.3, random_state = 176)
# Print a few rows
Train.head()
# Out:
#                    Crop  2004-05  2005-06  2006-07  2007-08  2008-09  2009-10  \
# 6                  Milk    100.0     97.0     98.0     98.0     98.0    112.0
# 7   Eggs, Fish and Meat    100.0    102.0    101.0    100.0     99.0    116.0
# 9            Sugarcane     100.0     96.0     91.0     87.0     80.0     81.0
# 10               Fibers    100.0     92.0     91.0     96.0    109.0    107.0
# 12                  NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#     2010-11  2011-12
# 6     123.0    124.0
# 7     133.0    137.0
# 9     109.0    107.0
# 10    138.0    140.0
# 12      NaN      NaN

# %%
Train_IndepentVars = Train.values[:, 3:5]
Train_TargetVar = Train.values[:,5]

# %%
rf_model =  RandomForestClassifier(max_depth=10,n_estimators=10)
rf_model.fit(Train_IndepentVars,Train_TargetVar)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-be921c432749> in <module>()
#       1 rf_model =  RandomForestClassifier(max_depth=10,n_estimators=10)
# ----> 2 rf_model.fit(Train_IndepentVars,Train_TargetVar)
#
# /usr/local/lib/python3.7/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     248
#     249         # Validate or convert input data
# --> 250         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     251         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     252         if sample_weight is not None:
#
# /usr/local/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
# ...
